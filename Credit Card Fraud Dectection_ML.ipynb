# %% [markdown]
# # Week 06 – Binary Classification: Credit Card Fraud Detection
# ### Build & Compare Three Classification Models
# **Dataset:** [Credit Card Fraud Detection – Kaggle](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud)
# **Models:** Logistic Regression · Decision Tree · K-Nearest Neighbours
# **Author:** *(Olajumoke)*  **Date:** 04-2026

# %% [markdown]
# STEP 1: Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec

# %% [markdown]
# STEP 2:Loading the data

# %%
df = pd.read_csv(r"C:\Users\J-Moke2022\Desktop\Data\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df['Class'].unique()
# Out:
# array([0, 1])

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# STEP 3: Analyzing Class Distribution
#  1.Check dist. of fraudulent transactions vs. normal dist.
#  2.Check outlier fraction along with with the number of fraud and valid transactions.
#  This is crucial in fraud detection ,as it reveals how rare fraud cases are and whether techniques like resampling or special evaluation metrics are needed.

# %%
fraud = df[df['Class'] == 1]
valid = df[df['Class'] == 0]
outlierFraction = len(fraud)/float(len(valid))
print(outlierFraction)
print('Fraud Cases: {}'.format(len(df[df['Class'] == 1])))
print('Valid Transactions: {}'.format(len(df[df['Class'] == 0])))
# Out:
# 0.0017304750013189597
# Fraud Cases: 492
# Valid Transactions: 284315

# %% [markdown]
# **The dataset is highly imbalanced with only 0.0017% of fradulent transactions.**
# **lets first try building a model without balancing the dataset.**

# %% [markdown]
# STEP 4: Exploring Transaction Amounts for F and V transactions

# %%
print('Amount details of Fraudulent transactions')
fraud['Amount'].describe()
# Out:
# Amount details of Fraudulent transactions
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
print('Details of Valid Transactions')
valid['Amount'].describe()
# Out:
# Details of Valid Transactions
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#From the output we observe that Fraudulent transactions Mean have higher average amount.

# %% [markdown]
# STEP 5: Plotting Correlation Matrix--Heatmap(To show how different features are related and the ones that will be relevant for prediction.)

# %%
corrmat = df.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Most features show weak correlation , indicating low multicollinearity.**
# **A few variables show moderate relationships with the Target Variable ,which will be useful for our Prediction.**

# %% [markdown]
# STEP 6: Preparing Data

# %%
X = df.drop(['Class'], axis = 1)
Y = df["Class"]
print(X.shape)
print(Y.shape)

xData = X.values
yData = Y.values

from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(
        xData, yData, test_size = 0.2, random_state = 42)
# Out:
# (284807, 30)
# (284807,)

# %% [markdown]
# Step 7: Building and Training the Model
# Train a Random Forest Classifier to predict fraudulent transactions.

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(
    n_estimators=50,
    max_depth=10,
    n_jobs=-1,
    random_state=42
)
print('Start Training...')
print('Training on', xTrain.shape[0], 'samples and', xTrain.shape[1], 'features')
rfc.fit(xTrain, yTrain)

print('Training Completed!')
yPred = rfc.predict(xTest)
# Out:
# Start Training...
# Training on 227845 samples and 30 features
# Training Completed!

# %% [markdown]
# Step 8: Evaluating the Model
# After training the model we need to evaluate its performance using various metrics such as accuracy, precision, recall, F1-score and the Matthews correlation coefficient.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, matthews_corrcoef, confusion_matrix 
accuracy = accuracy_score(yTest, yPred)
precision = precision_score(yTest, yPred)
recall = recall_score(yTest, yPred)
f1 = f1_score(yTest, yPred)
mcc = matthews_corrcoef(yTest, yPred)

print("Model Evaluation Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"Matthews Correlation Coefficient: {mcc:.4f}")

conf_matrix = confusion_matrix(yTest, yPred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Normal', 'Fraud'], yticklabels=['Normal', 'Fraud'])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.show()
# Out:
# Model Evaluation Metrics:
# Accuracy: 0.9995
# Precision: 0.9737
# Recall: 0.7551
# F1-Score: 0.8506
# Matthews Correlation Coefficient: 0.8573

# %% [markdown]
# The model accuracy is high due to class imbalance so Precision,Recall,F1 score was computed to get a more meaningful understanding.

# %% [markdown]
# We can balance dataset by oversampling the minority class or by undersampling the majority class to increase the accuracy of our model.
